# %%
# Importing all required Python 3 modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
gen_Germany = pd.read_csv("C:/time_series_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DE')),
                        parse_dates=[0], index_col=0)

# %%
gen_Germany.head(3)
# Out:
#                      DE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                          NaN
# 2005-01-01 00:00:00                                          NaN
# 2005-01-01 01:00:00                                          NaN
#
#                      DE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                      NaN
# 2005-01-01 00:00:00                                      NaN
# 2005-01-01 01:00:00                                      NaN
#
#                      DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2004-12-31 23:00:00                                   NaN
# 2005-01-01 00:00:00                                   NaN
# 2005-01-01 01:00:00                                   NaN
#
#                      DE_price_day_ahead_Energinet.dk_[EUR]  \
# utc_timestamp
# 2004-12-31 23:00:00                                  20.05
# ...

# %%
gen_Denmark = pd.read_csv("C:/time_series_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DK')),
                        parse_dates=[0], index_col=0)

# %%
gen_Denmark.head(3)
# Out:
#                      DK_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                          NaN
# 2005-01-01 00:00:00                                          NaN
# 2005-01-01 01:00:00                                          NaN
#
#                      DK_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                      NaN
# 2005-01-01 00:00:00                                      NaN
# 2005-01-01 01:00:00                                      NaN
#
#                      DK_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                        NaN
# 2005-01-01 00:00:00                                        NaN
# 2005-01-01 01:00:00                                        NaN
#
#                      DK_solar_capacity_[MW]  DK_solar_generation_actual_[MW]  \
# utc_timestamp
# ...

# %%
gen_Britain = pd.read_csv("C:/time_series_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('GB')),
                        parse_dates=[0], index_col=0)

# %%
gen_Britain.head(3)
# Out:
#                      GB_EAW_load_actual_tso_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                          NaN
# 2005-01-01 00:00:00                          NaN
# 2005-01-01 01:00:00                          NaN
#
#                      GB_GBN_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                              NaN
# 2005-01-01 00:00:00                                              NaN
# 2005-01-01 01:00:00                                              NaN
#
#                      GB_GBN_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                          NaN
# 2005-01-01 00:00:00                                          NaN
# 2005-01-01 01:00:00                                          NaN
#
#                      GB_GBN_load_actual_gross_generation_tso_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                           NaN
# ...

# %%
gen_Sweden = pd.read_csv("C:/time_series_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('SE')),
                        parse_dates=[0], index_col=0)

# %%
gen_Sweden.head(3)
# Out:
#                      SE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                          NaN
# 2005-01-01 00:00:00                                          NaN
# 2005-01-01 01:00:00                                          NaN
#
#                      SE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                      NaN
# 2005-01-01 00:00:00                                      NaN
# 2005-01-01 01:00:00                                      NaN
#
#                      SE_load_actual_tso_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                -15991.34
# 2005-01-01 00:00:00                -15673.12
# 2005-01-01 01:00:00                -15431.81
#
#                      SE_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                        NaN
# 2005-01-01 00:00:00                                        NaN
# ...

# %%
gen_Germany.tail(3)
# Out:
#                      DE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      DE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  44594.0
# 2019-04-30 22:00:00                                  42599.0
# 2019-04-30 23:00:00                                      NaN
#
#                      DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2019-04-30 21:00:00                               41060.0
# 2019-04-30 22:00:00                               39328.0
# 2019-04-30 23:00:00                                   NaN
#
#                      DE_price_day_ahead_Energinet.dk_[EUR]  \
# utc_timestamp
# 2019-04-30 21:00:00                                    NaN
# ...

# %%
gen_Denmark.tail(3)
# Out:
#                      DK_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      DK_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  2884.93
# 2019-04-30 22:00:00                                      NaN
# 2019-04-30 23:00:00                                      NaN
#
#                      DK_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                     2868.5
# 2019-04-30 22:00:00                                        NaN
# 2019-04-30 23:00:00                                        NaN
#
#                      DK_solar_capacity_[MW]  DK_solar_generation_actual_[MW]  \
# utc_timestamp
# ...

# %%
gen_Britain.tail(3)
# Out:
#                      GB_EAW_load_actual_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                          NaN
# 2019-04-30 22:00:00                          NaN
# 2019-04-30 23:00:00                          NaN
#
#                      GB_GBN_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                              NaN
# 2019-04-30 22:00:00                                              NaN
# 2019-04-30 23:00:00                                              NaN
#
#                      GB_GBN_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                      29245.0
# 2019-04-30 22:00:00                                      26692.0
# 2019-04-30 23:00:00                                          NaN
#
#                      GB_GBN_load_actual_gross_generation_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                           NaN
# ...

# %%
gen_Sweden.tail(3)
# Out:
#                      SE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      SE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  12072.0
# 2019-04-30 22:00:00                                      NaN
# 2019-04-30 23:00:00                                      NaN
#
#                      SE_load_actual_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                      NaN
# 2019-04-30 22:00:00                      NaN
# 2019-04-30 23:00:00                      NaN
#
#                      SE_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                    12740.0
# 2019-04-30 22:00:00                                        NaN
# ...

# %%
# use Pandas command .index to select data sets between 2015 and 2019

# %%
gen_Germany2 = gen_Germany.loc[gen_Germany.index.year >= 2010, :]

# %%
gen_Germany2.head(3)
# Out:
#                      DE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                   47645.0549
# 2010-01-01 01:00:00                                   45689.0110
# 2010-01-01 02:00:00                                   44218.6813
#
#                      DE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                      NaN
# 2010-01-01 01:00:00                                      NaN
# 2010-01-01 02:00:00                                      NaN
#
#                      DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2010-01-01 00:00:00                                   NaN
# 2010-01-01 01:00:00                                   NaN
# 2010-01-01 02:00:00                                   NaN
#
#                      DE_price_day_ahead_Energinet.dk_[EUR]  \
# utc_timestamp
# 2010-01-01 00:00:00                                  20.08
# ...

# %%
gen_Germany2.tail(3)
# Out:
#                      DE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      DE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  44594.0
# 2019-04-30 22:00:00                                  42599.0
# 2019-04-30 23:00:00                                      NaN
#
#                      DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2019-04-30 21:00:00                               41060.0
# 2019-04-30 22:00:00                               39328.0
# 2019-04-30 23:00:00                                   NaN
#
#                      DE_price_day_ahead_Energinet.dk_[EUR]  \
# utc_timestamp
# 2019-04-30 21:00:00                                    NaN
# ...

# %%
gen_Denmark2 = gen_Denmark.loc[gen_Denmark.index.year >= 2010, :]

# %%
gen_Britain2 = gen_Britain.loc[gen_Britain.index.year >= 2010, :]

# %%
gen_Sweden2 = gen_Sweden.loc[gen_Sweden.index.year >= 2010, :]

# %%
gen_Denmark2.head(3)
# Out:
#                      DK_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                       3528.0
# 2010-01-01 01:00:00                                       3391.0
# 2010-01-01 02:00:00                                       3302.0
#
#                      DK_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                      NaN
# 2010-01-01 01:00:00                                      NaN
# 2010-01-01 02:00:00                                      NaN
#
#                      DK_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                        NaN
# 2010-01-01 01:00:00                                        NaN
# 2010-01-01 02:00:00                                        NaN
#
#                      DK_solar_capacity_[MW]  DK_solar_generation_actual_[MW]  \
# utc_timestamp
# ...

# %%
gen_Denmark2.tail(3)
# Out:
#                      DK_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      DK_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  2884.93
# 2019-04-30 22:00:00                                      NaN
# 2019-04-30 23:00:00                                      NaN
#
#                      DK_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                     2868.5
# 2019-04-30 22:00:00                                        NaN
# 2019-04-30 23:00:00                                        NaN
#
#                      DK_solar_capacity_[MW]  DK_solar_generation_actual_[MW]  \
# utc_timestamp
# ...

# %%
gen_Britain.tail(3)
# Out:
#                      GB_EAW_load_actual_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                          NaN
# 2019-04-30 22:00:00                          NaN
# 2019-04-30 23:00:00                          NaN
#
#                      GB_GBN_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                              NaN
# 2019-04-30 22:00:00                                              NaN
# 2019-04-30 23:00:00                                              NaN
#
#                      GB_GBN_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                      29245.0
# 2019-04-30 22:00:00                                      26692.0
# 2019-04-30 23:00:00                                          NaN
#
#                      GB_GBN_load_actual_gross_generation_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                           NaN
# ...

# %%
gen_Britain.head(3)
# Out:
#                      GB_EAW_load_actual_tso_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                          NaN
# 2005-01-01 00:00:00                          NaN
# 2005-01-01 01:00:00                          NaN
#
#                      GB_GBN_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                              NaN
# 2005-01-01 00:00:00                                              NaN
# 2005-01-01 01:00:00                                              NaN
#
#                      GB_GBN_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                          NaN
# 2005-01-01 00:00:00                                          NaN
# 2005-01-01 01:00:00                                          NaN
#
#                      GB_GBN_load_actual_gross_generation_tso_[MW]  \
# utc_timestamp
# 2004-12-31 23:00:00                                           NaN
# ...

# %%
gen_Sweden2.head(3)
# Out:
#                      SE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                      18177.0
# 2010-01-01 01:00:00                                      18002.0
# 2010-01-01 02:00:00                                      17897.0
#
#                      SE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                      NaN
# 2010-01-01 01:00:00                                      NaN
# 2010-01-01 02:00:00                                      NaN
#
#                      SE_load_actual_tso_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                -17746.51
# 2010-01-01 01:00:00                -17573.55
# 2010-01-01 02:00:00                -17470.57
#
#                      SE_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2010-01-01 00:00:00                                        NaN
# 2010-01-01 01:00:00                                        NaN
# ...

# %%
gen_Sweden2.tail(3)
# Out:
#                      SE_load_actual_entsoe_power_statistics_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                          NaN
# 2019-04-30 22:00:00                                          NaN
# 2019-04-30 23:00:00                                          NaN
#
#                      SE_load_actual_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                  12072.0
# 2019-04-30 22:00:00                                      NaN
# 2019-04-30 23:00:00                                      NaN
#
#                      SE_load_actual_tso_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                      NaN
# 2019-04-30 22:00:00                      NaN
# 2019-04-30 23:00:00                      NaN
#
#                      SE_load_forecast_entsoe_transparency_[MW]  \
# utc_timestamp
# 2019-04-30 21:00:00                                    12740.0
# 2019-04-30 22:00:00                                        NaN
# ...

# %%
# AS next step, the resulting data-sets are explored using the info() command

# %%
gen_Germany2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 58 columns):
# DE_load_actual_entsoe_power_statistics_[MW]             79629 non-null float64
# DE_load_actual_entsoe_transparency_[MW]                 37945 non-null float64
# DE_load_forecast_entsoe_transparency                    37753 non-null float64
# DE_price_day_ahead_Energinet.dk_[EUR]                   81107 non-null float64
# DE_solar_capacity_[MW]                                  79391 non-null float64
# DE_solar_generation_solar_[MW]                          64190 non-null float64
# DE_solar_profile_[fraction]                             61819 non-null float64
# DE_wind_capacity_[MW]                                   79391 non-null float64
# DE_wind_generation_actual_[MW]                          81757 non-null float64
# DE_wind_profile_[fraction]                              79383 non-null float64
# ...

# %%
gen_Denmark2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 34 columns):
# DK_load_actual_entsoe_power_statistics_[MW]           81044 non-null float64
# DK_load_actual_entsoe_transparency_[MW]               37943 non-null float64
# DK_load_forecast_entsoe_transparency_[MW]             37943 non-null float64
# DK_solar_capacity_[MW]                                79390 non-null float64
# DK_solar_generation_actual_[MW]                       37936 non-null float64
# DK_wind_capacity_[MW]                                 79390 non-null float64
# DK_wind_offshore_capacity_[MW]                        79390 non-null float64
# DK_wind_offshore_generation_actual_[MW]               72357 non-null float64
# DK_wind_onshore_capacity_[MW]                         79390 non-null float64
# DK_wind_onshore_generation_actual_[MW]                72357 non-null float64
# ...

# %%
gen_Britain2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 44 columns):
# GB_EAW_load_actual_tso_[MW]                        78479 non-null float64
# GB_GBN_load_actual_entsoe_power_statistics_[MW]    51838 non-null float64
# GB_GBN_load_actual_entsoe_transparency_[MW]        38027 non-null float64
# GB_GBN_load_actual_gross_generation_tso_[MW]       78479 non-null float64
# GB_GBN_load_actual_tso_[MW]                        78479 non-null float64
# GB_GBN_load_foreacast_entsoe_transparency_[MW]     38088 non-null float64
# GB_GBN_price_day_ahead_[GBP]                       38206 non-null float64
# GB_GBN_solar_capacity_[MW]                         70489 non-null float64
# GB_GBN_solar_generation_actual_[MW]                76302 non-null float64
# GB_GBN_solar_generation_actual_dso_[MW]            76302 non-null float64
# GB_GBN_solar_generation_actual_tso_[MW]            81765 non-null float64
# ...

# %%
gen_Sweden2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 24 columns):
# SE_load_actual_entsoe_power_statistics_[MW]    78885 non-null float64
# SE_load_actual_entsoe_transparency_[MW]        37848 non-null float64
# SE_load_actual_tso_[MW]                        78885 non-null float64
# SE_load_forecast_entsoe_transparency_[MW]      37799 non-null float64
# SE_price_day_ahead_[EUR]                       16051 non-null float64
# SE_solar_generation_actual_[MW]                74538 non-null float64
# SE_wind_generation_actual_[MW]                 78885 non-null float64
# SE_wind_onshore_generation_actual_[MW]         38039 non-null float64
# SE_1_load_actual_entsoe_transparency_[MW]      38298 non-null float64
# SE_1_load_forecast_entsoe_transparency_[MW]    38183 non-null float64
# SE_1_price_day_ahead_[EUR]                     38327 non-null float64
# ...

# %%
# Data Analysis - Centered around Graphical Analysis

# %%
# Time Series Plot - Actual Wind Generation and Solar Generation - Superimposed
plt.plot(gen_Germany2.index, gen_Germany2['DE_wind_generation_actual_[MW]'])
plt.title('Actual wind generation in Germany in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 50000)

plt.plot(gen_Germany2.index, gen_Germany2['DE_solar_generation_solar_[MW]'])
plt.title('Actual Solar generation in Germany in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 50000)
# Out:
# (0, 50000)

# %%
# Time Series Plot - Same as above, both super imposed 
plt.plot(gen_Denmark2.index, gen_Denmark2['DK_1_wind_generation_actual_[MW]'])
plt.title('Actual wind generation in Denmark in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 10000)

plt.plot(gen_Denmark2.index, gen_Denmark2['DK_solar_generation_actual_[MW]'])
plt.title('Actual solar generation in Denmark in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 4500)
# Out:
# (0, 4500)

# %%
# Time Series Plot
plt.plot(gen_Britain2.index, gen_Britain2['GB_GBN_wind_generation_actual_[MW]'])
plt.title('Actual wind generation in Britain in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 15000)

plt.plot(gen_Britain2.index, gen_Britain2['GB_GBN_solar_generation_actual_[MW]'])
plt.title('Actual solar generation in Britain in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 15000)
# Out:
# (0, 15000)

# %%
# Time Series Plot
plt.plot(gen_Sweden2.index, gen_Sweden2['SE_wind_generation_actual_[MW]'])
plt.title('Actual wind generation in Sweden in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 8000)

plt.plot(gen_Sweden2.index, gen_Sweden2['SE_solar_generation_actual_[MW]'])
plt.title('Actual solar generation in Sweden in MW')
plt.xlim(pd.Timestamp('2010-01-01'), pd.Timestamp('2019-04-30'))
plt.ylim(0, 30000)
# Out:
# (0, 30000)

# %%
weather = pd.read_csv("c:/weather_cleaned.csv",
                     parse_dates=[0], index_col=0)

# %%
weather_short = pd.read_csv("c:/weather_cleaned_short.csv",
                     parse_dates=[0], index_col=0)

# %%
weather_short.head(3)
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2009-01-01 00:00:00          -1.254                             0.0
# 2009-01-01 01:00:00          -1.283                             0.0
# 2009-01-01 02:00:00          -1.337                             0.0
#
#                      GB_radiation_diffuse_horizontal  GR_temperature  \
# utc_timestamp
# 2009-01-01 00:00:00                              0.0           2.795
# 2009-01-01 01:00:00                              0.0           2.757
# 2009-01-01 02:00:00                              0.0           2.689
#
#                      GR_radiation_direct_horizontal  \
# utc_timestamp
# 2009-01-01 00:00:00                             0.0
# 2009-01-01 01:00:00                             0.0
# 2009-01-01 02:00:00                             0.0
#
#                      GR_radiation_diffuse_horizontal  SE_temperature  \
# utc_timestamp
# ...

# %%
weather_short.tail(3)
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2016-12-31 21:00:00           6.000                             0.0
# 2016-12-31 22:00:00           5.892                             0.0
# 2016-12-31 23:00:00           5.753                             0.0
#
#                      GB_radiation_diffuse_horizontal  GR_temperature  \
# utc_timestamp
# 2016-12-31 21:00:00                              0.0           2.239
# 2016-12-31 22:00:00                              0.0           2.125
# 2016-12-31 23:00:00                              0.0           1.959
#
#                      GR_radiation_direct_horizontal  \
# utc_timestamp
# 2016-12-31 21:00:00                             0.0
# 2016-12-31 22:00:00                             0.0
# 2016-12-31 23:00:00                             0.0
#
#                      GR_radiation_diffuse_horizontal  SE_temperature  \
# utc_timestamp
# ...

# %%
weather_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 70128 entries, 2009-01-01 00:00:00 to 2016-12-31 23:00:00
# Data columns (total 17 columns):
# GB_temperature                     70128 non-null float64
# GB_radiation_direct_horizontal     70128 non-null float64
# GB_radiation_diffuse_horizontal    70128 non-null float64
# GR_temperature                     70128 non-null float64
# GR_radiation_direct_horizontal     70128 non-null float64
# GR_radiation_diffuse_horizontal    70128 non-null float64
# SE_temperature                     70128 non-null float64
# SE_radiation_direct_horizontal     70128 non-null float64
# SE_radiation_diffuse_horizontal    70128 non-null float64
# DE_windspeed_10m                   70128 non-null float64
# DE_temperature                     70128 non-null float64
# DE_radiation_direct_horizontal     70128 non-null float64
# DE_radiation_diffuse_horizontal    70128 non-null float64
# DK_windspeed_10m                   70128 non-null float64
# ...

# %%
weather_short.loc[weather_short.index == '2012-01-01T00:00:00Z', :]
# Out:
#                GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01              9.992                             0.0
#
#                GB_radiation_diffuse_horizontal  GR_temperature  \
# utc_timestamp
# 2012-01-01                                 0.0            3.79
#
#                GR_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01                                0.0
#
#                GR_radiation_diffuse_horizontal  SE_temperature  \
# utc_timestamp
# 2012-01-01                                 0.0          -3.693
#
#                SE_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01                                0.0
#
#                SE_radiation_diffuse_horizontal  DE_windspeed_10m  \
# utc_timestamp
# 2012-01-01                                 0.0            4.8564
#
#                DE_temperature  DE_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01              4.951                             0.0
#
# ...

# %%
weather_short.loc[weather_short.index >= '2012-01-01T00:00:00Z', :]
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01 00:00:00           9.992                          0.0000
# 2012-01-01 01:00:00           9.776                          0.0000
# 2012-01-01 02:00:00           9.596                          0.0000
# 2012-01-01 03:00:00           9.390                          0.0000
# 2012-01-01 04:00:00           9.168                          0.0000
# 2012-01-01 05:00:00           8.931                          0.0000
# 2012-01-01 06:00:00           8.706                          0.0000
# 2012-01-01 07:00:00           8.530                          0.0000
# 2012-01-01 08:00:00           8.370                          0.1731
# 2012-01-01 09:00:00           8.495                          2.7781
# 2012-01-01 10:00:00           8.853                          6.9705
# 2012-01-01 11:00:00           9.184                          6.4008
# 2012-01-01 12:00:00           9.321                          3.5384
# ...

# %%
weather_short_by_day = weather_short.groupby(weather_short.index).mean()

# %%
weather_short_by_day.head(24)
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2009-01-01 00:00:00          -1.254                          0.0000
# 2009-01-01 01:00:00          -1.283                          0.0000
# 2009-01-01 02:00:00          -1.337                          0.0000
# 2009-01-01 03:00:00          -1.317                          0.0000
# 2009-01-01 04:00:00          -1.262                          0.0000
# 2009-01-01 05:00:00          -1.238                          0.0000
# 2009-01-01 06:00:00          -1.208                          0.0000
# 2009-01-01 07:00:00          -1.185                          0.0000
# 2009-01-01 08:00:00          -1.032                          1.1163
# 2009-01-01 09:00:00          -0.217                         12.5063
# 2009-01-01 10:00:00           0.622                         42.0984
# 2009-01-01 11:00:00           1.356                         75.3426
# 2009-01-01 12:00:00           1.891                         79.1936
# ...

# %%
weather_short_by_day.loc[weather_short_by_day.index >= '2012-01-01', :]
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2012-01-01 00:00:00           9.992                          0.0000
# 2012-01-01 01:00:00           9.776                          0.0000
# 2012-01-01 02:00:00           9.596                          0.0000
# 2012-01-01 03:00:00           9.390                          0.0000
# 2012-01-01 04:00:00           9.168                          0.0000
# 2012-01-01 05:00:00           8.931                          0.0000
# 2012-01-01 06:00:00           8.706                          0.0000
# 2012-01-01 07:00:00           8.530                          0.0000
# 2012-01-01 08:00:00           8.370                          0.1731
# 2012-01-01 09:00:00           8.495                          2.7781
# 2012-01-01 10:00:00           8.853                          6.9705
# 2012-01-01 11:00:00           9.184                          6.4008
# 2012-01-01 12:00:00           9.321                          3.5384
# ...

# %%
# create plot - in degrees Celsius
plt.plot(weather_short_by_day.index, weather_short_by_day['GB_temperature'])
plt.title('Great Britain _Temperature (Celsius)')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-10, 32)
# Out:
# (-10, 32)

# %%
# create plot - in degrees Celsius
plt.plot(weather_short_by_day.index, weather_short_by_day['SE_temperature'])
plt.title('Sweden _Temperature (Celsius)')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-20, 32)
# Out:
# (-20, 32)

# %%
# create plot - in degrees Celsius
plt.plot(weather_short_by_day.index, weather_short_by_day['DE_temperature'])
plt.title('Germany_Temperature (Celsius)')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-20, 39)
# Out:
# (-20, 39)

# %%
# create plot - in degrees Celsius
plt.plot(weather_short_by_day.index, weather_short_by_day['DK_temperature'])
plt.title('Denmark_Temperature (Celsius)')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-20, 30)
# Out:
# (-20, 30)

# %%
# create plot - Direct Horizontal Radiation
plt.plot(weather_short_by_day.index, weather_short_by_day['GB_radiation_direct_horizontal'])
plt.title('GB-radiation_direct_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 900)
# Out:
# (-5, 900)

# %%
# create plot - Direct Horizontal Radiation
plt.plot(weather_short_by_day.index, weather_short_by_day['SE_radiation_direct_horizontal'])
plt.title('SE-radiation_direct_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 900)
# Out:
# (-5, 900)

# %%
# create plot - Direct Horizontal Radiation
plt.plot(weather_short_by_day.index, weather_short_by_day['DE_radiation_direct_horizontal'])
plt.title('DE-radiation_direct_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 900)
# Out:
# (-5, 900)

# %%
# create plot - Direct Horizontal Radiation
plt.plot(weather_short_by_day.index, weather_short_by_day['DK_radiation_direct_horizontal'])
plt.title('DK-radiation_direct_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 900)
# Out:
# (-5, 900)

# %%
# create plot - Direct Diffuse Horizontal
plt.plot(weather_short_by_day.index, weather_short_by_day['GB_radiation_diffuse_horizontal'])
plt.title('GB-radiation_diffuse_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 400)
# Out:
# (-5, 400)

# %%
# create plot - Direct Diffuse Horizontal
plt.plot(weather_short_by_day.index, weather_short_by_day['SE_radiation_diffuse_horizontal'])
plt.title('SE-radiation_diffuse_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 400)
# Out:
# (-5, 400)

# %%
# create plot - Direct Diffuse Horizontal
plt.plot(weather_short_by_day.index, weather_short_by_day['DE_radiation_diffuse_horizontal'])
plt.title('DE-radiation_diffuse_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 400)
# Out:
# (-5, 400)

# %%
# create plot - Direct Diffuse Horizontal
plt.plot(weather_short_by_day.index, weather_short_by_day['DK_radiation_diffuse_horizontal'])
plt.title('DK-radiation_diffuse_horizontal')
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-12-31'))
plt.ylim(-5, 400)
# Out:
# (-5, 400)

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_DE = pd.merge('DE_wind_generation_actual_[MW]', weather_short_by_day, how='left', left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-54e57cd372dc> in <module>()
#       1 # merge production_wind_solar and weather_by_day DataFrames
# ----> 2 combined_DE = pd.merge('DE_wind_generation_actual_[MW]', weather_short_by_day, how='left', left_index=True, right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ...

# %%
# Need to eliminate the use of the brackets for the variable units in MegaWatts [MW]

# %%
gen2_Germany = pd.read_csv("C:/time_series2_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DE')),
                        parse_dates=[0], index_col=0)

# %%
gen2_Germany.head(3)
# Out:
#                      DE_load_actual_entsoe_power_statistics  \
# utc_timestamp
# 2004-12-31 23:00:00                                     NaN
# 2005-01-01 00:00:00                                     NaN
# 2005-01-01 01:00:00                                     NaN
#
#                      DE_load_actual_entsoe_transparency  \
# utc_timestamp
# 2004-12-31 23:00:00                                 NaN
# 2005-01-01 00:00:00                                 NaN
# 2005-01-01 01:00:00                                 NaN
#
#                      DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2004-12-31 23:00:00                                   NaN
# 2005-01-01 00:00:00                                   NaN
# 2005-01-01 01:00:00                                   NaN
#
#                      DE_price_day_ahead_Energinet.dk  DE_solar_capacity  \
# utc_timestamp
# 2004-12-31 23:00:00                            20.05             1118.0
# ...

# %%
gen2_Britain = pd.read_csv("C:/time_series2_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('GB')),
                        parse_dates=[0], index_col=0)

# %%
gen2_Britain.head(3)
# Out:
#                      GB_EAW_load_actual_tso  \
# utc_timestamp
# 2004-12-31 23:00:00                     NaN
# 2005-01-01 00:00:00                     NaN
# 2005-01-01 01:00:00                     NaN
#
#                      GB_GBN_load_actual_entsoe_power_statistics  \
# utc_timestamp
# 2004-12-31 23:00:00                                         NaN
# 2005-01-01 00:00:00                                         NaN
# 2005-01-01 01:00:00                                         NaN
#
#                      GB_GBN_load_actual_entsoe_transparency  \
# utc_timestamp
# 2004-12-31 23:00:00                                     NaN
# 2005-01-01 00:00:00                                     NaN
# 2005-01-01 01:00:00                                     NaN
#
#                      GB_GBN_load_actual_gross_generation_tso  \
# utc_timestamp
# 2004-12-31 23:00:00                                      NaN
# 2005-01-01 00:00:00                                      NaN
# ...

# %%
gen2_Denmark = pd.read_csv("C:/time_series2_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DK')),
                        parse_dates=[0], index_col=0)

# %%
gen2_Denmark.head(3)
# Out:
#                      DK_load_actual_entsoe_power_statistics  \
# utc_timestamp
# 2004-12-31 23:00:00                                     NaN
# 2005-01-01 00:00:00                                     NaN
# 2005-01-01 01:00:00                                     NaN
#
#                      DK_load_actual_entsoe_transparency  \
# utc_timestamp
# 2004-12-31 23:00:00                                 NaN
# 2005-01-01 00:00:00                                 NaN
# 2005-01-01 01:00:00                                 NaN
#
#                      DK_load_forecast_entsoe_transparency  DK_solar_capacity  \
# utc_timestamp
# 2004-12-31 23:00:00                                   NaN                2.0
# 2005-01-01 00:00:00                                   NaN                2.0
# 2005-01-01 01:00:00                                   NaN                2.0
#
#                      DK_solar_generation_actual  DK_wind_capacity  \
# utc_timestamp
# ...

# %%
gen2_Sweden = pd.read_csv("C:/time_series2_cleaned_60min.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('SE')),
                        parse_dates=[0], index_col=0)

# %%
gen2_Sweden.head(3)
# Out:
#                      SE_load_actual_entsoe_power_statistics  \
# utc_timestamp
# 2004-12-31 23:00:00                                     NaN
# 2005-01-01 00:00:00                                     NaN
# 2005-01-01 01:00:00                                     NaN
#
#                      SE_load_actual_entsoe_transparency  SE_load_actual_tso  \
# utc_timestamp
# 2004-12-31 23:00:00                                 NaN           -15991.34
# 2005-01-01 00:00:00                                 NaN           -15673.12
# 2005-01-01 01:00:00                                 NaN           -15431.81
#
#                      SE_load_forecast_entsoe_transparency  SE_price_day_ahead  \
# utc_timestamp
# 2004-12-31 23:00:00                                   NaN                 NaN
# 2005-01-01 00:00:00                                   NaN                 NaN
# 2005-01-01 01:00:00                                   NaN                 NaN
#
# ...

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_DE = pd.merge(gen2_Germany['DE_wind_generation_actual'], weather_short_by_day, how='left', left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-51e402298f88> in <module>()
#       1 # merge production_wind_solar and weather_by_day DataFrames
# ----> 2 combined_DE = pd.merge(gen2_Germany['DE_wind_generation_actual'], weather_short_by_day, how='left', left_index=True, right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ...

# %%
gen2_Germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125593 entries, 2004-12-31 23:00:00 to 2019-04-30 23:00:00
# Data columns (total 58 columns):
# DE_load_actual_entsoe_power_statistics             114694 non-null float64
# DE_load_actual_entsoe_transparency                 37945 non-null float64
# DE_load_forecast_entsoe_transparency               37753 non-null float64
# DE_price_day_ahead_Energinet.dk                    124927 non-null float64
# DE_solar_capacity                                  123216 non-null float64
# DE_solar_generation_solar                          64190 non-null float64
# DE_solar_profile                                   61819 non-null float64
# DE_wind_capacity                                   123216 non-null float64
# DE_wind_generation_actual                          81758 non-null float64
# DE_wind_profile                                    79384 non-null float64
# DE_wind_offshore_capacity                          82994 non-null float64
# ...

# %%
Germany_prod = gen2_Germany[['DE_wind_generation_actual','DE_solar_generation_solar']]

# %%
gen2_Britain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125593 entries, 2004-12-31 23:00:00 to 2019-04-30 23:00:00
# Data columns (total 44 columns):
# GB_EAW_load_actual_tso                        120145 non-null float64
# GB_GBN_load_actual_entsoe_power_statistics    51838 non-null float64
# GB_GBN_load_actual_entsoe_transparency        38027 non-null float64
# GB_GBN_load_actual_gross_generation_tso       120145 non-null float64
# GB_GBN_load_actual_tso                        120145 non-null float64
# GB_GBN_load_foreacast_entsoe_transparency     38088 non-null float64
# GB_GBN_price_day_ahead                        38206 non-null float64
# GB_GBN_solar_capacity                         70489 non-null float64
# GB_GBN_solar_generation_actual                76302 non-null float64
# GB_GBN_solar_generation_actual_dso            76302 non-null float64
# GB_GBN_solar_generation_actual_tso            91873 non-null float64
# ...

# %%
Britain_prod = gen2_Britain[['GB_GBN_wind_generation_actual','GB_GBN_solar_generation_actual']]

# %%
gen2_Denmark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125593 entries, 2004-12-31 23:00:00 to 2019-04-30 23:00:00
# Data columns (total 34 columns):
# DK_load_actual_entsoe_power_statistics            81045 non-null float64
# DK_load_actual_entsoe_transparency                37943 non-null float64
# DK_load_forecast_entsoe_transparency              37943 non-null float64
# DK_solar_capacity                                 123215 non-null float64
# DK_solar_generation_actual                        37936 non-null float64
# DK_wind_capacity                                  123215 non-null float64
# DK_wind_offshore_capacity                         123215 non-null float64
# DK_wind_offshore_generation_actual                72357 non-null float64
# DK_wind_onshore_capacity                          123215 non-null float64
# DK_wind_onshore_generation_actual                 72357 non-null float64
# DK_1_load_actual_entsoe_power_statistics          35062 non-null float64
# ...

# %%
Denmark_prod = gen2_Denmark[['DK_1_wind_generation_actual','DK_1_solar_generation_actual']]

# %%
gen2_Sweden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125593 entries, 2004-12-31 23:00:00 to 2019-04-30 23:00:00
# Data columns (total 24 columns):
# SE_load_actual_entsoe_power_statistics    78886 non-null float64
# SE_load_actual_entsoe_transparency        37848 non-null float64
# SE_load_actual_tso                        122710 non-null float64
# SE_load_forecast_entsoe_transparency      37799 non-null float64
# SE_price_day_ahead                        51112 non-null float64
# SE_solar_generation_actual                74538 non-null float64
# SE_wind_generation_actual                 122710 non-null float64
# SE_wind_onshore_generation_actual         38039 non-null float64
# SE_1_load_actual_entsoe_transparency      38298 non-null float64
# SE_1_load_forecast_entsoe_transparency    38183 non-null float64
# SE_1_price_day_ahead                      38327 non-null float64
# SE_1_wind_onshore_generation_actual       38039 non-null float64
# ...

# %%
Sweden_prod = gen2_Sweden[['SE_wind_generation_actual','SE_solar_generation_actual']]

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_DE = pd.merge(Germany_prod, weather_short_by_day, how='left', left_index=True, right_index=True)

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_GB = pd.merge(Britain_prod, weather_short_by_day, how='left', left_index=True, right_index=True)

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_DK = pd.merge(Denmark_prod, weather_short_by_day, how='left', left_index=True, right_index=True)

# %%
# merge production_wind_solar and weather_by_day DataFrames
combined_SE = pd.merge(Sweden_prod, weather_short_by_day, how='left', left_index=True, right_index=True)

# %%
combined_DE.head()
# Out:
#                      DE_wind_generation_actual  DE_solar_generation_solar  \
# utc_timestamp
# 2004-12-31 23:00:00                        NaN                        NaN
# 2005-01-01 00:00:00                        NaN                        NaN
# 2005-01-01 01:00:00                        NaN                        NaN
# 2005-01-01 02:00:00                        NaN                        NaN
# 2005-01-01 03:00:00                        NaN                        NaN
#
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2004-12-31 23:00:00             NaN                             NaN
# 2005-01-01 00:00:00             NaN                             NaN
# 2005-01-01 01:00:00             NaN                             NaN
# 2005-01-01 02:00:00             NaN                             NaN
# 2005-01-01 03:00:00             NaN                             NaN
#
#                      GB_radiation_diffuse_horizontal  GR_temperature  \
# ...

# %%
combined_DK.head()
# Out:
#                      DK_1_wind_generation_actual  \
# utc_timestamp
# 2004-12-31 23:00:00                        278.1
# 2005-01-01 00:00:00                        294.9
# 2005-01-01 01:00:00                        304.5
# 2005-01-01 02:00:00                        322.4
# 2005-01-01 03:00:00                        349.2
#
#                      DK_1_solar_generation_actual  GB_temperature  \
# utc_timestamp
# 2004-12-31 23:00:00                           NaN             NaN
# 2005-01-01 00:00:00                           NaN             NaN
# 2005-01-01 01:00:00                           NaN             NaN
# 2005-01-01 02:00:00                           NaN             NaN
# 2005-01-01 03:00:00                           NaN             NaN
#
#                      GB_radiation_direct_horizontal  \
# utc_timestamp
# 2004-12-31 23:00:00                             NaN
# 2005-01-01 00:00:00                             NaN
# 2005-01-01 01:00:00                             NaN
# ...

# %%
combined_SE.head()
# Out:
#                      SE_wind_generation_actual  SE_solar_generation_actual  \
# utc_timestamp
# 2004-12-31 23:00:00                       3.22                         NaN
# 2005-01-01 00:00:00                       2.84                         NaN
# 2005-01-01 01:00:00                       2.57                         NaN
# 2005-01-01 02:00:00                       3.12                         NaN
# 2005-01-01 03:00:00                       4.68                         NaN
#
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2004-12-31 23:00:00             NaN                             NaN
# 2005-01-01 00:00:00             NaN                             NaN
# 2005-01-01 01:00:00             NaN                             NaN
# 2005-01-01 02:00:00             NaN                             NaN
# 2005-01-01 03:00:00             NaN                             NaN
#
#                      GB_radiation_diffuse_horizontal  GR_temperature  \
# ...

# %%
combined_GB.head()
# Out:
#                      GB_GBN_wind_generation_actual  \
# utc_timestamp
# 2004-12-31 23:00:00                            NaN
# 2005-01-01 00:00:00                            NaN
# 2005-01-01 01:00:00                            NaN
# 2005-01-01 02:00:00                            NaN
# 2005-01-01 03:00:00                            NaN
#
#                      GB_GBN_solar_generation_actual  GB_temperature  \
# utc_timestamp
# 2004-12-31 23:00:00                             NaN             NaN
# 2005-01-01 00:00:00                             NaN             NaN
# 2005-01-01 01:00:00                             NaN             NaN
# 2005-01-01 02:00:00                             NaN             NaN
# 2005-01-01 03:00:00                             NaN             NaN
#
#                      GB_radiation_direct_horizontal  \
# utc_timestamp
# 2004-12-31 23:00:00                             NaN
# 2005-01-01 00:00:00                             NaN
# ...

# %%
combined2_DK = combined_DK.loc[combined_DK.index.year >= 2010, :]

# %%
combined2_DE = combined_DE.loc[combined_DE.index.year >= 2010, :]

# %%
combined2_GB = combined_GB.loc[combined_GB.index.year >= 2010, :]

# %%
combined2_SE = combined_SE.loc[combined_SE.index.year >= 2010, :]

# %%
combined2_DK.dtypes
# Out:
# DK_1_wind_generation_actual        float64
# DK_1_solar_generation_actual       float64
# GB_temperature                     float64
# GB_radiation_direct_horizontal     float64
# GB_radiation_diffuse_horizontal    float64
# GR_temperature                     float64
# GR_radiation_direct_horizontal     float64
# GR_radiation_diffuse_horizontal    float64
# SE_temperature                     float64
# SE_radiation_direct_horizontal     float64
# SE_radiation_diffuse_horizontal    float64
# DE_windspeed_10m                   float64
# DE_temperature                     float64
# DE_radiation_direct_horizontal     float64
# DE_radiation_diffuse_horizontal    float64
# DK_windspeed_10m                   float64
# DK_temperature                     float64
# DK_radiation_direct_horizontal     float64
# DK_radiation_diffuse_horizontal    float64
# dtype: object

# %%
sns.pairplot(combined2_DK, x_vars=['DK_temperature', 'DK_radiation_direct_horizontal', 'DK_radiation_diffuse_horizontal', 'DK_windspeed_10m'], y_vars=['DK_1_wind_generation_actual'])

# %%
combined2_GB.dtypes
# Out:
# GB_GBN_wind_generation_actual      float64
# GB_GBN_solar_generation_actual     float64
# GB_temperature                     float64
# GB_radiation_direct_horizontal     float64
# GB_radiation_diffuse_horizontal    float64
# GR_temperature                     float64
# GR_radiation_direct_horizontal     float64
# GR_radiation_diffuse_horizontal    float64
# SE_temperature                     float64
# SE_radiation_direct_horizontal     float64
# SE_radiation_diffuse_horizontal    float64
# DE_windspeed_10m                   float64
# DE_temperature                     float64
# DE_radiation_direct_horizontal     float64
# DE_radiation_diffuse_horizontal    float64
# DK_windspeed_10m                   float64
# DK_temperature                     float64
# DK_radiation_direct_horizontal     float64
# DK_radiation_diffuse_horizontal    float64
# dtype: object

# %%
sns.pairplot(combined2_DE, x_vars=['DE_temperature', 'DE_radiation_direct_horizontal', 'DE_radiation_diffuse_horizontal', 'DE_windspeed_10m'], y_vars=['DE_wind_generation_actual'])

# %%
sns.pairplot(combined2_GB, x_vars=['GB_temperature', 'GB_radiation_direct_horizontal', 'GB_radiation_diffuse_horizontal'], y_vars=['GB_GBN_wind_generation_actual'])

# %%
sns.pairplot(combined2_SE, x_vars=['SE_temperature', 'SE_radiation_direct_horizontal', 'SE_radiation_diffuse_horizontal'], y_vars=['SE_wind_generation_actual'])

# %%
sns.pairplot(combined2_DK, x_vars=['DK_temperature', 'DK_radiation_direct_horizontal', 'DK_radiation_diffuse_horizontal', 'DK_windspeed_10m'], y_vars=['DK_1_solar_generation_actual'])

# %%
combined2_DE.dtypes
# Out:
# DE_wind_generation_actual          float64
# DE_solar_generation_solar          float64
# GB_temperature                     float64
# GB_radiation_direct_horizontal     float64
# GB_radiation_diffuse_horizontal    float64
# GR_temperature                     float64
# GR_radiation_direct_horizontal     float64
# GR_radiation_diffuse_horizontal    float64
# SE_temperature                     float64
# SE_radiation_direct_horizontal     float64
# SE_radiation_diffuse_horizontal    float64
# DE_windspeed_10m                   float64
# DE_temperature                     float64
# DE_radiation_direct_horizontal     float64
# DE_radiation_diffuse_horizontal    float64
# DK_windspeed_10m                   float64
# DK_temperature                     float64
# DK_radiation_direct_horizontal     float64
# DK_radiation_diffuse_horizontal    float64
# dtype: object

# %%
sns.pairplot(combined2_DE, x_vars=['DE_temperature', 'DE_radiation_direct_horizontal', 'DE_radiation_diffuse_horizontal', 'DE_windspeed_10m'], y_vars=['DE_solar_generation_solar'])

# %%
sns.pairplot(combined2_GB, x_vars=['GB_temperature', 'GB_radiation_direct_horizontal', 'GB_radiation_diffuse_horizontal'], y_vars=['GB_GBN_solar_generation_actual'])

# %%
sns.pairplot(combined2_SE, x_vars=['SE_temperature', 'SE_radiation_direct_horizontal', 'SE_radiation_diffuse_horizontal'], y_vars=['SE_solar_generation_actual'])

# %%
sns.jointplot(x='DE_temperature', y='DE_wind_generation_actual', data=combined2_DE, kind='reg')
sns.jointplot(x='DE_radiation_direct_horizontal', y='DE_wind_generation_actual', data=combined2_DE, kind='reg')
sns.jointplot(x='DE_radiation_diffuse_horizontal', y='DE_wind_generation_actual', data=combined2_DE, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='DE_temperature', y='DE_solar_generation_solar', data=combined2_DE, kind='reg')
sns.jointplot(x='DE_radiation_direct_horizontal', y='DE_solar_generation_solar', data=combined2_DE, kind='reg')
sns.jointplot(x='DE_radiation_diffuse_horizontal', y='DE_solar_generation_solar', data=combined2_DE, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='DK_temperature', y='DK_1_wind_generation_actual', data=combined2_DK, kind='reg')
sns.jointplot(x='DK_radiation_direct_horizontal', y='DK_1_wind_generation_actual', data=combined2_DK, kind='reg')
sns.jointplot(x='DK_radiation_diffuse_horizontal', y='DK_1_wind_generation_actual', data=combined2_DK, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='DK_temperature', y='DK_1_solar_generation_actual', data=combined2_DK, kind='reg')
sns.jointplot(x='DK_radiation_direct_horizontal', y='DK_1_solar_generation_actual', data=combined2_DK, kind='reg')
sns.jointplot(x='DK_radiation_diffuse_horizontal', y='DK_1_solar_generation_actual', data=combined2_DK, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='SE_temperature', y='SE_wind_generation_actual', data=combined2_SE, kind='reg')
sns.jointplot(x='SE_radiation_direct_horizontal', y='SE_wind_generation_actual', data=combined2_SE, kind='reg')
sns.jointplot(x='SE_radiation_diffuse_horizontal', y='SE_wind_generation_actual', data=combined2_SE, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='SE_temperature', y='SE_solar_generation_actual', data=combined2_SE, kind='reg')
sns.jointplot(x='SE_radiation_direct_horizontal', y='SE_solar_generation_actual', data=combined2_SE, kind='reg')
sns.jointplot(x='SE_radiation_diffuse_horizontal', y='SE_solar_generation_actual', data=combined2_SE, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='GB_temperature', y='GB_GBN_wind_generation_actual', data=combined2_GB, kind='reg')
sns.jointplot(x='GB_radiation_direct_horizontal', y='GB_GBN_wind_generation_actual', data=combined2_GB, kind='reg')
sns.jointplot(x='GB_radiation_diffuse_horizontal', y='GB_GBN_wind_generation_actual', data=combined2_GB, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
sns.jointplot(x='GB_temperature', y='GB_GBN_solar_generation_actual', data=combined2_GB, kind='reg')
sns.jointplot(x='GB_radiation_direct_horizontal', y='GB_GBN_solar_generation_actual', data=combined2_GB, kind='reg')
sns.jointplot(x='GB_radiation_diffuse_horizontal', y='GB_GBN_solar_generation_actual', data=combined2_GB, kind='reg')
# Out:
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rjsie\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %%
#We willuse the linear regression model from the SciKit Learn library

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()

# %%
DE_X_wind = combined2_DE[['DE_temperature', 'DE_radiation_direct_horizontal', 'DE_radiation_diffuse_horizontal', 'DE_windspeed_10m']]

# %% [markdown]
# combined2_DK.info()

# %%
combined2_DE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 19 columns):
# DE_wind_generation_actual          81757 non-null float64
# DE_solar_generation_solar          64190 non-null float64
# GB_temperature                     61361 non-null float64
# GB_radiation_direct_horizontal     61361 non-null float64
# GB_radiation_diffuse_horizontal    61361 non-null float64
# GR_temperature                     61361 non-null float64
# GR_radiation_direct_horizontal     61361 non-null float64
# GR_radiation_diffuse_horizontal    61361 non-null float64
# SE_temperature                     61361 non-null float64
# SE_radiation_direct_horizontal     61361 non-null float64
# SE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# ...

# %%
DK_X_wind = combined2_DK[['DK_temperature', 'DK_radiation_direct_horizontal', 'DK_radiation_diffuse_horizontal', 'DK_windspeed_10m']]

# %%
combined2_DK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 19 columns):
# DK_1_wind_generation_actual        81116 non-null float64
# DK_1_solar_generation_actual       46376 non-null float64
# GB_temperature                     61361 non-null float64
# GB_radiation_direct_horizontal     61361 non-null float64
# GB_radiation_diffuse_horizontal    61361 non-null float64
# GR_temperature                     61361 non-null float64
# GR_radiation_direct_horizontal     61361 non-null float64
# GR_radiation_diffuse_horizontal    61361 non-null float64
# SE_temperature                     61361 non-null float64
# SE_radiation_direct_horizontal     61361 non-null float64
# SE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# ...

# %%
SE_X_wind = combined2_SE[['SE_temperature', 'SE_radiation_direct_horizontal', 'SE_radiation_diffuse_horizontal']]

# %%
combined2_SE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 19 columns):
# SE_wind_generation_actual          78885 non-null float64
# SE_solar_generation_actual         74538 non-null float64
# GB_temperature                     61361 non-null float64
# GB_radiation_direct_horizontal     61361 non-null float64
# GB_radiation_diffuse_horizontal    61361 non-null float64
# GR_temperature                     61361 non-null float64
# GR_radiation_direct_horizontal     61361 non-null float64
# GR_radiation_diffuse_horizontal    61361 non-null float64
# SE_temperature                     61361 non-null float64
# SE_radiation_direct_horizontal     61361 non-null float64
# SE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# ...

# %%
GB_X_wind = combined2_GB[['GB_temperature', 'GB_radiation_direct_horizontal', 'GB_radiation_diffuse_horizontal']]

# %%
combined2_GB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 19 columns):
# GB_GBN_wind_generation_actual      78479 non-null float64
# GB_GBN_solar_generation_actual     76302 non-null float64
# GB_temperature                     61361 non-null float64
# GB_radiation_direct_horizontal     61361 non-null float64
# GB_radiation_diffuse_horizontal    61361 non-null float64
# GR_temperature                     61361 non-null float64
# GR_radiation_direct_horizontal     61361 non-null float64
# GR_radiation_diffuse_horizontal    61361 non-null float64
# SE_temperature                     61361 non-null float64
# SE_radiation_direct_horizontal     61361 non-null float64
# SE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# ...

# %%
DE_Y_wind = combined2_DE[['DE_wind_generation_actual']]

# %%
DK_Y_wind = combined2_DK[['DK_1_wind_generation_actual']]

# %%
SE_Y_wind = combined2_SE[['SE_wind_generation_actual']]

# %%
GB_Y_wind = combined2_GB[['GB_GBN_wind_generation_actual']]

# %%
scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-5beda6b7fcff> in <module>()
# ----> 1 scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
#       2 print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
# ...

# %%
# Due to error message shown above, we will analyze the datasets for NaN values and/or other discrepancies

# %%
DE_X_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 4 columns):
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# DE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# dtypes: float64(4)
# memory usage: 3.1 MB

# %%
DE_Y_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 1 columns):
# DE_wind_generation_actual    81757 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
DE_X_wind.head(3)
# Out:
#                      DE_temperature  DE_radiation_direct_horizontal  \
# utc_timestamp
# 2010-01-01 00:00:00          -1.352                             0.0
# 2010-01-01 01:00:00          -1.537                             0.0
# 2010-01-01 02:00:00          -1.727                             0.0
#
#                      DE_radiation_diffuse_horizontal  DE_windspeed_10m
# utc_timestamp
# 2010-01-01 00:00:00                              0.0            3.9374
# 2010-01-01 01:00:00                              0.0            3.9878
# 2010-01-01 02:00:00                              0.0            3.9901

# %%
DE_X_wind.tail(3)
# Out:
#                      DE_temperature  DE_radiation_direct_horizontal  \
# utc_timestamp
# 2019-04-30 21:00:00             NaN                             NaN
# 2019-04-30 22:00:00             NaN                             NaN
# 2019-04-30 23:00:00             NaN                             NaN
#
#                      DE_radiation_diffuse_horizontal  DE_windspeed_10m
# utc_timestamp
# 2019-04-30 21:00:00                              NaN               NaN
# 2019-04-30 22:00:00                              NaN               NaN
# 2019-04-30 23:00:00                              NaN               NaN

# %%
DE_Y_wind.head(5)
# Out:
#                      DE_wind_generation_actual
# utc_timestamp
# 2010-01-01 00:00:00                     3414.0
# 2010-01-01 01:00:00                     3318.0
# 2010-01-01 02:00:00                     3058.0
# 2010-01-01 03:00:00                     3110.0
# 2010-01-01 04:00:00                     2866.0

# %%
DE_Y_wind.tail(5)
# Out:
#                      DE_wind_generation_actual
# utc_timestamp
# 2019-04-30 19:00:00                     8659.0
# 2019-04-30 20:00:00                     8414.0
# 2019-04-30 21:00:00                        NaN
# 2019-04-30 22:00:00                        NaN
# 2019-04-30 23:00:00                        NaN

# %%
DK_X_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 4 columns):
# DK_temperature                     61361 non-null float64
# DK_radiation_direct_horizontal     61361 non-null float64
# DK_radiation_diffuse_horizontal    61361 non-null float64
# DK_windspeed_10m                   61361 non-null float64
# dtypes: float64(4)
# memory usage: 3.1 MB

# %%
DK_Y_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 1 columns):
# DK_1_wind_generation_actual    81116 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
DK_X_wind.head(5)
# Out:
#                      DK_temperature  DK_radiation_direct_horizontal  \
# utc_timestamp
# 2010-01-01 00:00:00          -5.602                             0.0
# 2010-01-01 01:00:00          -5.606                             0.0
# 2010-01-01 02:00:00          -5.667                             0.0
# 2010-01-01 03:00:00          -5.724                             0.0
# 2010-01-01 04:00:00          -5.784                             0.0
#
#                      DK_radiation_diffuse_horizontal  DK_windspeed_10m
# utc_timestamp
# 2010-01-01 00:00:00                              0.0              4.43
# 2010-01-01 01:00:00                              0.0              4.39
# 2010-01-01 02:00:00                              0.0              4.32
# 2010-01-01 03:00:00                              0.0              4.32
# 2010-01-01 04:00:00                              0.0              4.42

# %%
DK_X_wind.tail(6)
# Out:
#                      DK_temperature  DK_radiation_direct_horizontal  \
# utc_timestamp
# 2019-04-30 18:00:00             NaN                             NaN
# 2019-04-30 19:00:00             NaN                             NaN
# 2019-04-30 20:00:00             NaN                             NaN
# 2019-04-30 21:00:00             NaN                             NaN
# 2019-04-30 22:00:00             NaN                             NaN
# 2019-04-30 23:00:00             NaN                             NaN
#
#                      DK_radiation_diffuse_horizontal  DK_windspeed_10m
# utc_timestamp
# 2019-04-30 18:00:00                              NaN               NaN
# 2019-04-30 19:00:00                              NaN               NaN
# 2019-04-30 20:00:00                              NaN               NaN
# 2019-04-30 21:00:00                              NaN               NaN
# 2019-04-30 22:00:00                              NaN               NaN
# ...

# %%
DK_Y_wind.head(5)
# Out:
#                      DK_1_wind_generation_actual
# utc_timestamp
# 2010-01-01 00:00:00                        186.1
# 2010-01-01 01:00:00                        211.7
# 2010-01-01 02:00:00                        215.1
# 2010-01-01 03:00:00                        248.5
# 2010-01-01 04:00:00                        220.8

# %%
DK_Y_wind.tail(5)
# Out:
#                      DK_1_wind_generation_actual
# utc_timestamp
# 2019-04-30 19:00:00                          NaN
# 2019-04-30 20:00:00                          NaN
# 2019-04-30 21:00:00                          NaN
# 2019-04-30 22:00:00                          NaN
# 2019-04-30 23:00:00                          NaN

# %%
SE_X_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 3 columns):
# SE_temperature                     61361 non-null float64
# SE_radiation_direct_horizontal     61361 non-null float64
# SE_radiation_diffuse_horizontal    61361 non-null float64
# dtypes: float64(3)
# memory usage: 2.5 MB

# %%
SE_Y_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 1 columns):
# SE_wind_generation_actual    78885 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
SE_X_wind.head(5)
# Out:
#                      SE_temperature  SE_radiation_direct_horizontal  \
# utc_timestamp
# 2010-01-01 00:00:00         -11.328                             0.0
# 2010-01-01 01:00:00         -11.328                             0.0
# 2010-01-01 02:00:00         -11.261                             0.0
# 2010-01-01 03:00:00         -11.031                             0.0
# 2010-01-01 04:00:00         -10.817                             0.0
#
#                      SE_radiation_diffuse_horizontal
# utc_timestamp
# 2010-01-01 00:00:00                              0.0
# 2010-01-01 01:00:00                              0.0
# 2010-01-01 02:00:00                              0.0
# 2010-01-01 03:00:00                              0.0
# 2010-01-01 04:00:00                              0.0

# %%
SE_X_wind.tail(5)
# Out:
#                      SE_temperature  SE_radiation_direct_horizontal  \
# utc_timestamp
# 2019-04-30 19:00:00             NaN                             NaN
# 2019-04-30 20:00:00             NaN                             NaN
# 2019-04-30 21:00:00             NaN                             NaN
# 2019-04-30 22:00:00             NaN                             NaN
# 2019-04-30 23:00:00             NaN                             NaN
#
#                      SE_radiation_diffuse_horizontal
# utc_timestamp
# 2019-04-30 19:00:00                              NaN
# 2019-04-30 20:00:00                              NaN
# 2019-04-30 21:00:00                              NaN
# 2019-04-30 22:00:00                              NaN
# 2019-04-30 23:00:00                              NaN

# %%
SE_Y_wind.head(5)
# Out:
#                      SE_wind_generation_actual
# utc_timestamp
# 2010-01-01 00:00:00                     206.23
# 2010-01-01 01:00:00                     218.00
# 2010-01-01 02:00:00                     214.40
# 2010-01-01 03:00:00                     220.48
# 2010-01-01 04:00:00                     237.48

# %%
SE_Y_wind.tail(5)
# Out:
#                      SE_wind_generation_actual
# utc_timestamp
# 2019-04-30 19:00:00                        NaN
# 2019-04-30 20:00:00                        NaN
# 2019-04-30 21:00:00                        NaN
# 2019-04-30 22:00:00                        NaN
# 2019-04-30 23:00:00                        NaN

# %%
GB_X_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 3 columns):
# GB_temperature                     61361 non-null float64
# GB_radiation_direct_horizontal     61361 non-null float64
# GB_radiation_diffuse_horizontal    61361 non-null float64
# dtypes: float64(3)
# memory usage: 2.5 MB

# %%
GB_Y_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81768 entries, 2010-01-01 00:00:00 to 2019-04-30 23:00:00
# Data columns (total 1 columns):
# GB_GBN_wind_generation_actual    78479 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
GB_X_wind.head(5)
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2010-01-01 00:00:00          -1.096                             0.0
# 2010-01-01 01:00:00          -1.202                             0.0
# 2010-01-01 02:00:00          -1.271                             0.0
# 2010-01-01 03:00:00          -1.331                             0.0
# 2010-01-01 04:00:00          -1.428                             0.0
#
#                      GB_radiation_diffuse_horizontal
# utc_timestamp
# 2010-01-01 00:00:00                              0.0
# 2010-01-01 01:00:00                              0.0
# 2010-01-01 02:00:00                              0.0
# 2010-01-01 03:00:00                              0.0
# 2010-01-01 04:00:00                              0.0

# %%
GB_X_wind.tail()
# Out:
#                      GB_temperature  GB_radiation_direct_horizontal  \
# utc_timestamp
# 2019-04-30 19:00:00             NaN                             NaN
# 2019-04-30 20:00:00             NaN                             NaN
# 2019-04-30 21:00:00             NaN                             NaN
# 2019-04-30 22:00:00             NaN                             NaN
# 2019-04-30 23:00:00             NaN                             NaN
#
#                      GB_radiation_diffuse_horizontal
# utc_timestamp
# 2019-04-30 19:00:00                              NaN
# 2019-04-30 20:00:00                              NaN
# 2019-04-30 21:00:00                              NaN
# 2019-04-30 22:00:00                              NaN
# 2019-04-30 23:00:00                              NaN

# %%
GB_Y_wind.head()
# Out:
#                      GB_GBN_wind_generation_actual
# utc_timestamp
# 2010-01-01 00:00:00                         1086.0
# 2010-01-01 01:00:00                         1102.0
# 2010-01-01 02:00:00                         1060.0
# 2010-01-01 03:00:00                          965.0
# 2010-01-01 04:00:00                          927.0

# %%
GB_Y_wind.tail()
# Out:
#                      GB_GBN_wind_generation_actual
# utc_timestamp
# 2019-04-30 19:00:00                            NaN
# 2019-04-30 20:00:00                            NaN
# 2019-04-30 21:00:00                            NaN
# 2019-04-30 22:00:00                            NaN
# 2019-04-30 23:00:00                            NaN

# %%
# Due to the presence of NaN values, we are using df = df.dropna() to drop the rows containing these values

# %%
DE_X_wind = DE_X_wind.dropna()

# %%
DE_X_wind.head(10)
# Out:
#                      DE_temperature  DE_radiation_direct_horizontal  \
# utc_timestamp
# 2010-01-01 00:00:00          -1.352                          0.0000
# 2010-01-01 01:00:00          -1.537                          0.0000
# 2010-01-01 02:00:00          -1.727                          0.0000
# 2010-01-01 03:00:00          -1.870                          0.0000
# 2010-01-01 04:00:00          -2.003                          0.0000
# 2010-01-01 05:00:00          -2.127                          0.0000
# 2010-01-01 06:00:00          -2.281                          0.0000
# 2010-01-01 07:00:00          -2.400                          0.1416
# 2010-01-01 08:00:00          -2.024                          2.4332
# 2010-01-01 09:00:00          -1.398                          8.4561
#
#                      DE_radiation_diffuse_horizontal  DE_windspeed_10m
# utc_timestamp
# 2010-01-01 00:00:00                           0.0000            3.9374
# ...

# %%
DE_X_wind.tail(10)
# Out:
#                      DE_temperature  DE_radiation_direct_horizontal  \
# utc_timestamp
# 2016-12-31 14:00:00           0.085                         17.6616
# 2016-12-31 15:00:00          -1.179                          0.5530
# 2016-12-31 16:00:00          -1.487                          0.0000
# 2016-12-31 17:00:00          -1.672                          0.0000
# 2016-12-31 18:00:00          -1.813                          0.0000
# 2016-12-31 19:00:00          -1.932                          0.0000
# 2016-12-31 20:00:00          -2.090                          0.0000
# 2016-12-31 21:00:00          -2.289                          0.0000
# 2016-12-31 22:00:00          -2.473                          0.0000
# 2016-12-31 23:00:00          -2.730                          0.0000
#
#                      DE_radiation_diffuse_horizontal  DE_windspeed_10m
# utc_timestamp
# 2016-12-31 14:00:00                          39.9574            3.3698
# ...

# %%
scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-209-5beda6b7fcff> in <module>()
# ----> 1 scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
#       2 print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     190
# ...

# %%
DE_Y_wind = DE_Y_wind.dropna()

# %%
scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-5beda6b7fcff> in <module>()
# ----> 1 scores_wind_DE = cross_val_score(lr, DE_X_wind, DE_Y_wind, cv=5)
#       2 print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     190
# ...

# %%
DE_X_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61361 entries, 2010-01-01 00:00:00 to 2016-12-31 23:00:00
# Data columns (total 4 columns):
# DE_temperature                     61361 non-null float64
# DE_radiation_direct_horizontal     61361 non-null float64
# DE_radiation_diffuse_horizontal    61361 non-null float64
# DE_windspeed_10m                   61361 non-null float64
# dtypes: float64(4)
# memory usage: 2.3 MB

# %%
DE_Y_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 81757 entries, 2010-01-01 00:00:00 to 2019-04-30 20:00:00
# Data columns (total 1 columns):
# DE_wind_generation_actual    81757 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
DE50000_X_wind = DE_X_wind[:50000]

# %%
DE50000_Y_wind = DE_Y_wind[:50000]

# %%
scores_wind_DE = cross_val_score(lr, DE50000_X_wind, DE50000_Y_wind, cv=5)
print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
# Out:
# [0.6782416  0.78601039 0.7435666  0.78598574 0.64116418]
# average = 0.7269937028275629

# %%
# A simplified approach for the other countries will consist of working only with the first 50000 rows

# %%
SE_X_wind = SE_X_wind.dropna()

# %%
SE_Y_wind = SE_Y_wind.dropna()

# %%
SE50000_X_wind = SE_X_wind[:50000]

# %%
SE50000_Y_wind = SE_Y_wind[:50000]

# %%
DK_X_wind = DK_X_wind.dropna()

# %%
DK_Y_wind = DK_Y_wind.dropna()

# %%
DK50000_X_wind = DK_X_wind[:50000]

# %%
DK50000_Y_wind = DK_Y_wind[:50000]

# %%
GB_X_wind = GB_X_wind.dropna()

# %%
GB_Y_wind = GB_Y_wind.dropna()

# %%
GB50000_X_wind = GB_X_wind[:50000]

# %%
GB50000_Y_wind = GB_Y_wind[:50000]

# %%
# Summary of Wind data tested with Linear Regression algorithm

# %%
scores_wind_DE = cross_val_score(lr, DE50000_X_wind, DE50000_Y_wind, cv=5)
print(scores_wind_DE, "\naverage =", np.mean(scores_wind_DE))
# Out:
# [0.6782416  0.78601039 0.7435666  0.78598574 0.64116418]
# average = 0.7269937028275629

# %%
scores_wind_SE = cross_val_score(lr, SE50000_X_wind, SE50000_Y_wind, cv=5)
print(scores_wind_SE, "\naverage =", np.mean(scores_wind_SE))
# Out:
# [-6.9919727  -0.25489787 -0.02426021 -0.06130562 -0.6847112 ]
# average = -1.6034295209508236

# %%
scores_wind_DK = cross_val_score(lr, DK50000_X_wind, DK50000_Y_wind, cv=5)
print(scores_wind_DK, "\naverage =", np.mean(scores_wind_DK))
# Out:
# [0.6039246  0.69125122 0.80725189 0.7090179  0.66535623]
# average = 0.6953603681320336

# %%
scores_wind_GB = cross_val_score(lr, GB50000_X_wind, GB50000_Y_wind, cv=5)
print(scores_wind_GB, "\naverage =", np.mean(scores_wind_GB))
# Out:
# [-3.29261787 -0.30091138  0.02778469 -0.08045655 -0.40501881]
# average = -0.8102439825261969

# %%
# Now we proceed to conduct the same analysis for the Solar Generation Solar

# %%
# We can keep the same "X" axis parameter in place.

# %%
DE_Y_solar = combined2_DE[['DE_solar_generation_solar']]

# %%
DE_Y_solar = DE_Y_solar.dropna()

# %%
DE50000_Y_solar = DE_Y_solar[:50000]

# %%
DK_Y_solar = combined2_DK[['DK_1_solar_generation_actual']]

# %%
DK_Y_solar = DK_Y_solar.dropna()

# %%
DK45000_Y_solar = DK_Y_solar[:45000]

# %%
DK45000_X_wind = DK_Y_wind[:45000]

# %%
SE_Y_solar = combined2_SE[['SE_solar_generation_actual']]

# %%
SE_Y_solar = SE_Y_solar.dropna()

# %%
SE50000_Y_solar = SE_Y_solar[:50000]

# %%
GB_Y_solar = combined2_GB[['GB_GBN_solar_generation_actual']]

# %%
GB_Y_solar = GB_Y_solar.dropna()

# %%
GB47000_Y_solar = GB_Y_solar[:47000]

# %%
GB47000_X_wind = GB50000_X_wind[:47000]

# %%
scores_solar_DE = cross_val_score(lr, DE50000_X_wind, DE50000_Y_solar, cv=5)
print(scores_solar_DE, "\naverage =", np.mean(scores_solar_DE))
# Out:
# [-0.92309326 -0.10978097  0.44140219  0.57089763  0.57172048]
# average = 0.11022921331950034

# %%
scores_solar_SE = cross_val_score(lr, SE50000_X_wind, SE50000_Y_solar, cv=5)
print(scores_solar_SE, "\naverage =", np.mean(scores_solar_SE))
# Out:
# [-1.46310788e+03 -4.52835862e+01 -9.94821577e-01  5.37557289e-02
#  -1.88267206e-01]
# average = -301.9041599359074

# %%
scores_solar_DK = cross_val_score(lr, DK45000_X_wind, DK45000_Y_solar, cv=5)
print(scores_solar_DK, "\naverage =", np.mean(scores_solar_DK))
# Out:
# [-0.03094905  0.00931171  0.01579143  0.02611322 -0.00424398]
# average = 0.0032046668637830456

# %%
scores_solar_GB = cross_val_score(lr, GB47000_X_wind, GB47000_Y_solar, cv=5)
print(scores_solar_GB, "\naverage =", np.mean(scores_solar_GB))
# Out:
# [-2.25405364 -0.78621567  0.00272781  0.02359805 -0.16917038]
# average = -0.6366227672727123

# %%
# ----   Evaluate other models

# %%
# --- Evaluating Ridge Model

# %%
from sklearn import linear_model

# %%
rg = linear_model.Ridge(alpha=5)

# %%
scores_solar_DERG = cross_val_score(rg, DE50000_X_wind, DE50000_Y_solar, cv=5)
print(scores_solar_DERG, "\naverage =", np.mean(scores_solar_DERG))
# Out:
# [-0.9230931  -0.10978112  0.44140219  0.5708977   0.57172077]
# average = 0.11022929018129637

# %%
scores_solar_DKRG = cross_val_score(rg, DK45000_X_wind, DK45000_Y_solar, cv=5)
print(scores_solar_DKRG, "\naverage =", np.mean(scores_solar_DKRG))
# Out:
# [-0.03094905  0.00931171  0.01579143  0.02611322 -0.00424398]
# average = 0.0032046668653092697

# %%
scores_solar_SERG = cross_val_score(rg, SE50000_X_wind, SE50000_Y_solar, cv=5)
print(scores_solar_SERG, "\naverage =", np.mean(scores_solar_SERG))
# Out:
# [-1.46310423e+03 -4.52835554e+01 -9.94820620e-01  5.37556060e-02
#  -1.88267234e-01]
# average = -301.9034234277406

# %%
scores_solar_GBRG = cross_val_score(rg, GB47000_X_wind, GB47000_Y_solar, cv=5)
print(scores_solar_GBRG, "\naverage =", np.mean(scores_solar_GBRG))
# Out:
# [-2.25404059 -0.78621431  0.00272816  0.0235978  -0.16917062]
# average = -0.6366199137849351

# %%
# ---  ----  -----

# %%
# --- Now, we evaluate the Lasso algorith, which estimates sparse coefficients

# %%
lasso = linear_model.Lasso(alpha=0.1)

# %%
scores_solar_DELasso = cross_val_score(rg, DE50000_X_wind, DE50000_Y_solar, cv=5)
print(scores_solar_DELasso, "\naverage =", np.mean(scores_solar_DELasso))
# Out:
# [-0.9230931  -0.10978112  0.44140219  0.5708977   0.57172077]
# average = 0.11022929018129637

# %%
scores_solar_DKLasso = cross_val_score(rg, DK45000_X_wind, DK45000_Y_solar, cv=5)
print(scores_solar_DKLasso, "\naverage =", np.mean(scores_solar_DKLasso))
# Out:
# [-0.03094905  0.00931171  0.01579143  0.02611322 -0.00424398]
# average = 0.0032046668653092697

# %%
scores_solar_SELasso = cross_val_score(rg, SE50000_X_wind, SE50000_Y_solar, cv=5)
print(scores_solar_SELasso, "\naverage =", np.mean(scores_solar_SELasso))
# Out:
# [-1.46310423e+03 -4.52835554e+01 -9.94820620e-01  5.37556060e-02
#  -1.88267234e-01]
# average = -301.9034234277406

# %%
scores_solar_GBLasso = cross_val_score(rg, GB47000_X_wind, GB47000_Y_solar, cv=5)
print(scores_solar_GBLasso, "\naverage =", np.mean(scores_solar_GBLasso))
# Out:
# [-2.25404059 -0.78621431  0.00272816  0.0235978  -0.16917062]
# average = -0.6366199137849351
